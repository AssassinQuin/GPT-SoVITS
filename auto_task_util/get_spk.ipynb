# %%
# from transformers import pipeline, AutoTokenizer
# import torch

# # model_name = "ckiplab/bert-base-chinese-ner"
# # model_name = "/root/download/robert_bilstm_mega_res-ner-msra-ner"
# model_name = "/root/download/bert_bilstm_crf-ner-weibo"

# def merge_entities(entities_list):
#     """
#     合并连续的实体
#     """
#     merged_entities = []
#     prev_entity = None

#     for entity in entities_list:
#         if (
#             prev_entity
#             and entity["entity_group"] == prev_entity["entity_group"]
#             and entity["start"] == prev_entity["end"]
#         ):
#             prev_entity["word"] += entity["word"]
#             prev_entity["end"] = entity["end"]
#         else:
#             if prev_entity:
#                 prev_entity["word"] = prev_entity["word"].strip().replace(" ", "")
#                 merged_entities.append(prev_entity)
#             prev_entity = entity

#     if prev_entity:
#         prev_entity["word"] = prev_entity["word"].strip().replace(" ", "")
#         merged_entities.append(prev_entity)

#     return merged_entities

# def detect_names(text):
#     """
#     使用预训练模型识别中文人名
#     :param text: 输入的文本内容
#     :return: 识别到的人名列表（已去重）
#     """
#     try:
#         # 检查GPU是否可用
#         device = 0 if torch.cuda.is_available() else -1

#         # 初始化模型组件
#         tokenizer = AutoTokenizer.from_pretrained(model_name)

#         # 创建NER处理管道（自动合并连续实体）
#         ner_model = pipeline(
#             task="ner",
#             model=model_name,
#             tokenizer=tokenizer,
#             aggregation_strategy="simple",  # 自动合并B - I标签的实体
#             device=device
#         )

#         # 执行实体识别（返回结构示例）
#         # [{'word': '王小明', 'score': 0.998, 'entity_group': 'PER', 'start': 0, 'end': 3}, ...]
#         res = []
#         repetition_map = set()

#         text_list = text.split("\n")
#         input_list = []

#         for idx in range(0, len(text_list)):
#             min_idx = max(0, idx-2)
#             max_idx = min(len(text_list), idx+2)
#             item = "\n".join(text_list[min_idx:max_idx])
#             input_list.append(item)

#         for item in input_list:
#             results = ner_model(item)
#             result = merge_entities(results)
#             for entity in result:
#                 if "PER" in entity["entity_group"]  and entity["score"] >= 0.9 and entity["word"] not in repetition_map:
#                     res.append(entity["word"])
#                     repetition_map.add(entity["word"])


#         return res
#     except Exception as e:
#         print(f"发生错误: {e}")
#         return []

# if __name__ == "__main__":
#     text = """
# 第76章 沸腾的五号无限城
# 　　哈总愤怒。
# 　　本来它还挺欣赏这个锻造师，但没想到，对方也是这样的人！
# 　　路然无奈，其实只要牙齿已经可以了，至少不用骨头，他抬头问：“对了，林大师，总共要多少晶币？”
# 　　林大师沉思：“我算算，在风陨剑的基础上，我融合了稀有资源巨灵矿，高级资源寒铁，轻石、重石，辅助锻造的普通矿物资源若干，再加上锻造费。”
# 　　“总价格，差不多是5万晶币吧，零头我给你抹了。”
# 　　路然虽然已经有了心理准备，但知道自己给哈总升级了一把新武器花了5万晶币后，还是肉疼无比。
# 　　他露出微微痛苦的表情，终于体会到了那些成年人还房贷的艰辛。
# 　　“年轻人，定力就是不行！”林大师摇头：“我再给你详细介绍一遍冰空大剑好了！”
# 　　“冰空大剑，两种形态可以自由切换，除了基础的能量传导、增幅效果，还附带三个技能，举重若轻、举轻若重、牙岚！”
# 　　“两种形态自由切换，可以使它应对不同对手时选择更加灵活，毕竟大剑形态消耗体力严重，不过相对的，它的攻击力，在稀有武器中，绝对是顶呱呱。”
# 　　“让它越个种族等级、成长等级，那是轻轻松松。”
# 　　“嗯，考虑到你的宠兽不断在成长，我还加入了轻、重石，剑的重量，可以根据它的成长情况由它自己调节，换句话来说，这是一把可以改变重量的剑！”
# 　　“而牙岚，是依托于那上百颗牙齿的一个技能，是蕴含在剑内部的剑技，假如你的宠兽一丝能量也没有了，并且到了极为危机的时刻，可以牺牲那些内部的牙齿，换取一次超强的剑气爆发，瞬间挥出上百道剑气，算是一个压箱技。”
# 　　“当然，用完之后剑也相当于半报废了，需要补充新牙齿才能修补。”
# 　　“总之，你们现在只是看到了表面功能，稀有武器没那么简单！怎么样，现在是不是感觉物有所值了？”
# 　　路然听完，只是同情的看向了哈总，只感觉更费牙了。
# 　　哈总：。
# 　　。
# 　　不久后，路然离开了锻造之家，带着一屁股欠债，来到了三号无限城的传送广场。
# 　　除了锻剑，路然还买了一个高级弓弩，用于涂毒，一身暗抗衣服，用于抵御废弃试验场的魔能气息，一共花了1288晶币。
# 　　“这一去，不知道什么时候能回来。”
# 　　站在巨大的传送门附近，路然也判断不好，如果不顺利，在那边待个十天半个月都是有可能的。
# 　　“不过，不得不去。”穿着黑夜大衣的路然，踏进了传送区。
# 　　【是否花费100晶币传送至夏国五号无限城。】
# 　　“是。”路然确认，下一刻，他的身影消失在了人山人海的传送广场。
# 　　紧接着，随着光芒闪烁，来到了自己的专属房间。
# 　　路然打开门，这一回外界，不是那个居民小区了，而是另外一个传送广场，此次从专属房间出来，他是从传送门的光屏中走出的。
# 　　“这里就是五号无限城了啊。”路然只是看了一眼外边，就又回到传送门内，进入了专属房间，说是御兽师传送，但更像是，整个专属房间的空间跟着一起传送了过来。
# 　　并且坑钱的是，这个时候路然根本无法直接下线，得传送回三号无限城，才能回归到现实的传送位置，也就是得再花100晶币才能回归。
# 　　无意义的花销，也让很多御兽师没心思去其他无限城串门，只安心挑战自己城池的秘境。
# 　　专属房间内，路然来到了秘境柱台前，看向眼前的光幕。
# 　　秘境种类已经更新，虽然这里面大部分秘境，都和三号无限城没什么区别，但还是有个别秘境，是三号无限城没有的。
# 　　比如，废弃试验场，就是这个无限城的特色秘境。
# 　　【名称：废弃试验场】
# 　　【秘境等级：新手】
# 　　【难度：深渊】
# 　　【挑战晶币：1000】
# 　　路然迟疑了一下，放弃了在五号无限城逛一逛的打算，想立刻就挑战一次这个秘境看看！
# 　　毕竟，他已经等了一周时间了！
# 　　这一周，也时刻在备战着，并非无所事事。
# 　　“哈总。”路然叫出了哈总，并把冰空大剑扔给它。
# 　　“嗷！”哈总一叼，表情严肃。
# 　　它也知道，接下来有一场硬仗！
# 　　。
# 　　此时此刻，五号无限城的御兽师们，还不知道三号无限城的路人甲，已经传送到了这里，并开始挑战当地的特色深渊秘境。
# 　　【传送完成。】
# 　　【目前地点：废弃试验场（新手秘境）】
# 　　【难度：深渊】
# 　　【挑战任务：击杀魔牛统领。】
# 　　【秘境介绍：为了迎接战争，御兽帝国开始秘密研究生物兵器，希望制造一批精通武器使用的战争巨兽。
# 　　但不料战争提前开启，帝国财政陷入紧张境地，这项计划被临时喊停。
# 　　无数试验场被废弃，其中个别试验场，还封印有计划的实验品。】
# 　　【提示①：新手秘境最长停留时限为8小时，期间试炼者可自主选择是否回归，传送需10秒时间。】
# 　　【提示②：。】
# 　　路然和哈总踩在冒着黑烟的大地上，望着前方坍塌的废弃试验场，微微一怔。
# 　　这个秘境的状况，看起来极为糟糕啊。
# 　　这里是。被所谓的战争给波及到了吗？不然就算废弃，也不至于这么混乱吧。
# 　　“还好提前做了准备。”路然按照顾博士给的攻略，准备了一身黑夜大衣，这里因为长时间进行黑暗生物实验，浸染了大量魔能气息，非常干扰精神意志，超凡生物或许影响不大，但对于人类而言，还是做下防护较好。
# 　　唰！
# 　　路然的黑夜大衣飘动，旁边，叼着原始状态·冰空大剑的哈总左右观察，询问路然敌人在哪。
# 　　“等一等。”路然看向了倒塌的废弃试验场，按照攻略所说，当挑战者进入试验场30秒后，魔牛统领就会破封而出。失控的实验品魔牛统领，将对附近的生命进行无差别攻击！
# 　　“吼！！！！！”
# 　　果然，三十秒一过，伴随巨吼，砰的一声，废弃试验场的坍塌建筑炸开，乱石纷飞，一道高达五、六米的庞大身影，慢慢从废墟中爬了出来。
# 　　所谓的魔牛统领，和牛头怪类似，是一种拥有类人形态、强壮肌肉的人身牛首怪物，路然他们看到的这一只，远远比普通牛头怪要更巨大，体型已经媲美牛头巨兽。
# 　　它手持暗影战斧，横扫开废弃的乱石，登上废墟，阴云之下，红色的眼瞳充满冷酷之色。
# 　　“嗷！！！”
# 　　此时，刚刚见面，哈总就甩出一道剑气，友好问候。
# 　　但面对这凌空而来的剑气，魔牛统领根本不屑一顾，任由它落在身上。
# 　　砰！
# 　　一阵烟尘过后，剑气只是在魔牛统领的胸膛，留下一道淡淡的白痕，甚至连防御都没有破开。
# 　　“果然，和攻略上说的一样，它没有躲避攻击的意识，即使是感觉到威胁，也只会用技能反击！”
# 　　路然让哈总实验了一下，再次验证攻略没什么问题。
# 　　“依然不废话，十倍暴风斩！”路然话落，哈总嗷呜了一声，下一瞬，它的武器转化为了大剑形态，规模堪比哈总自己的大剑被它叼在嘴中，格外有威慑力。
# 　　一股凌厉的气势，从哈总身上爆发。
# 　　暴风雪剑势！
# 　　但是，无往不利哪怕压制了龙尾蝎的暴风雪剑势，这一回面对魔牛统领，似乎并没有什么作用。
# 　　“吼！！！”
# 　　魔牛统领头颅一甩，它高举斧头，向着路然他们的方向重重一砸。
# 　　轰！！！
# 　　瞬间，庞大的黑暗冲击波，像汹涌的浪潮一般朝着路然他们吞噬而来。
# 　　不过转瞬之间，又有耀眼的冰蓝色斩击，犹如破浪之刃，将黑色冲击波一分为二，直至此时，魔牛统领的本能才察觉到了一丝危机！
# 　　汪！！！（这上百颗牙的功力，你挡得住吗？！）
# 　　十倍剑气压缩的暴风斩，配合新武器冰空大剑，一瞬之间，劈开魔牛统领释放的黑暗冲击波，落到魔牛统领身上。
# 　　与此同时，哈总口中流出鲜血，牙齿摇摇欲晃，满脸的凶狠。
# 　　正如它所说，这上百颗牙的功力，怎么挡啊！
# 　　它的身后，路然手持神鹿项坠，一瞬间把它的伤势治好。
# 　　不过虽然反伤治好，但这一道极限暴风斩，直接掏空了哈总大半的力气，它已经无法放出第二道。
# 　　十倍剑气压缩的暴风斩，消耗不代表就等同释放十道剑气，反而对哈总的消耗极大。
# 　　“嗷呜！！！”一击而过，哈总呲牙看着前方烟雾升腾的区域，路然也目光凝重，耳边迟迟没有提示音传来，路然知道，这足以把龙尾蝎打的渣都不剩的一击，没能对这只魔牛统领造成致命伤害。
# 　　也对，那只龙尾蝎，只是野生的，但魔牛统领，却是一个御兽文明高度发达的御兽帝国制造的战争兵器实验品，相当于有无数御兽师的智慧结晶浓缩在它身上，怎么可能好对付。
# 　　“吼！！！！”果然，下一瞬，路然和哈总，就听到了一声愤怒的咆哮，烟雾被强烈的劲风挥去，转眼，就看见一只浑身包裹由黑暗能量塑造的魔能铠甲的牛头巨兽踩踏着废墟狂奔而来！！
# 　　“汪！！”叼着剑的哈总目瞪狗呆。
# 　　咚咚咚！魔牛统领每踏一步，都是地动山摇！
# 　　“哈总你行不行。”路然转头就跑，道：“什么时候考虑下领悟20倍暴风斩？”
# 　　“汪！！”看到魔牛冲撞而来，哈总也转头就跑，并把路然翻到身上。
# 　　20倍。别说牙齿了，它的狗头怕不是也不保！
# 　　总之，现在路然和哈总都牙疼至极，虽然预料到了这一次可能无法秒杀对手，但是真正经历到，他们好慌。
# 　　“吼！！”此时的牛头巨兽，魔能铠甲碎裂无数，身上也有黑色的鲜血冒出，一颗黑色牛角都被削成两半，但依然保持着极为亢奋的状态，手持巨斧，向着路然和哈总冲来。
# 　　还好，对于这种情况，路然也早有预案，哈总身上，路然扭身瞬间，一把弓弩出现在了他手中。
# 　　“哈总！”
# 　　电光火石之间，路然将涂毒的弓箭射出，并且同一时间，哈总也进行转身，利用剩下的力气，猛然吹出风之咆哮。
# 　　“嗷呜！！！”
# 　　飓风加速了有毒弓箭的推进，魔牛统领依然对防御没有什么意识，只知道进攻，完全没有在意看起来毫无威力的弓箭，而面对哈总的风之咆哮，它的脚步也没有受到什么阻碍。
# 　　唰。
# 　　弓箭插入魔牛统领的魔能铠甲、伤口缝隙，它毫无感觉的继续冲着，而看到弓箭一发入魂对方却没什么反应，路然和哈总也只能继续跑，没有和魔牛统领硬碰硬的打算。
# 　　利用好速度优势。
# 　　风筝流！斗牛！
# 　　“吼！！！”见到伤到自己的敌人逃走，且速度极快，魔牛统领不再追击，继续愤怒的挥舞巨斧，一道黑暗冲击波再次朝着路然它们吞噬而来。
# 　　黑色冲击波扫过，大地出现巨大的裂痕，犹如被黑色火焰炙烤，眼看黑色冲击波快速接近，逃跑中的哈总背后展开一对风之翼，迅速带着路然飞向天空。
# 　　轰隆！
# 　　巨坑之上，路然再次拿出弓弩，对准魔牛统领的眼睛，直接射去！
# 　　“傻了吧，还好我有先见之明，让哈总学会了风之翼！”
# 　　嗖！
# 　　又一发弓箭直接爆眼，路然的猎人血脉展露无疑，完全是百发百中。
# 　　狗都会飞，魔牛统领更加暴怒，全身能量流动加快，转瞬间，破碎的魔能铠甲有修复的趋势，扎入胸口和眼睛的弓箭，也瞬间被狂暴流动的能量冲掉，路然看魔牛统领进入了狂暴状态，没有敢再射，而是拍着哈总道：“跑！”
# 　　“拖时间！”
# 　　路然也不知道方澜给的毒液管不管用，但见哈总利用十倍暴风斩配合稀有武器冰空大剑也只是重创魔牛统领而没能秒杀它，顿时知道为什么深渊难度的秘境很少有人能单刷通关了。
# 　　这种难度。就算是四人组队能通关，也十分了不起。
# 　　接下来，就是魔牛统领和哈总耐力的比拼，不过相比魔牛统领，路然他们这边有制空优势，有补品优势，哈总一边飞，路然一边给它灌冰蜜茶，恢复着它的体力。
# 　　下方，魔牛统领不断发泄怒火，力量狂暴的砸在天空、大地，每一次路然和哈总都感觉在翻车边缘晃悠，还好有着暴风雪秘境的特训经验，哈总每次都成功躲开冲击，不然即使神鹿项坠能治愈伤害，也够他们喝一壶了。
# 　　就这样，路然和哈总大概和魔牛统领周旋了十几分钟。
# 　　哈总已经累得不成样子，而魔牛统领依然看起来精力充沛，让路然头皮发麻。
# 　　就在路然考虑要不要先放弃这次秘境时，突然，一道天籁之音，让路然浑身一震。
# 　　【恭喜你完成秘境挑战。】
# 　　【评分：S级！】
# 　　【恭喜你获得800晶币。】
# 　　【恭喜你获得高级资源，暗影矿。】
# 　　【恭喜你获得特殊资源，升级卡。】
# 　　【恭喜你获得特殊资源，特质水晶（武器掌控）。】
# 　　
# 　　声音落下，路然直接傻眼，不断拍着哈总的脑袋，狠狠拽着它的狗毛，让胯下的哈总都害怕了。
# 　　“呜呜。”
# 　　不明白路然一时间为什么这么亢奋。
# 　　不就是一次失败吗？牛头兽，让路总疯掉，这个仇。
# 　　但转眼，哈总似乎也知道怎么回事了，它向下看去，露出睿智的表情！
# 　　只见此时，刚才还很暴躁无比的魔牛统领，突然站在了原地不动，像是瞬间失去了全部生机，发光的眼睛也暗淡了下来。
# 　　“哞。”
# 　　意外的，它最后一道悲怆的声音，路然和哈总感觉自己能听懂。
# 　　哞。（卑鄙的入侵者，箭里有毒。）
# 　　它目光充满了不甘，庞大的身躯，重重倒在了地上，连同武器，一起化为碎片，随风而去。
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

# model_name = "ckiplab/bert-base-chinese-ner"
# model_name = "/root/download/robert_bilstm_mega_res-ner-msra-ner"
# model_name = "/root/download/bert_bilstm_crf-ner-weibo"
model_name = "iic/nlp_raner_named-entity-recognition_chinese-base-book"

def merge_entities(entities_list):
    """
    合并连续的实体
    """
    merged_entities = []
    prev_entity = None

    for entity in entities_list:
        if (
            prev_entity
            and entity["entity_group"] == prev_entity["entity_group"]
            and entity["start"] == prev_entity["end"]
        ):
            prev_entity["word"] += entity["word"]
            prev_entity["end"] = entity["end"]
        else:
            if prev_entity:
                prev_entity["word"] = prev_entity["word"].strip().replace(" ", "")
                merged_entities.append(prev_entity)
            prev_entity = entity

    if prev_entity:
        prev_entity["word"] = prev_entity["word"].strip().replace(" ", "")
        merged_entities.append(prev_entity)

    return merged_entities

def detect_names(text):
    """
    使用预训练模型识别中文人名
    :param text: 输入的文本内容
    :return: 识别到的人名列表（已去重）
    """
    try:
        # 创建NER处理管道（自动合并连续实体）
        ner_model = pipeline(
            Tasks.named_entity_recognition,
            model_name,
            device="gpu"
        )

        # 执行实体识别（返回结构示例）
        # [{'word': '王小明', 'score': 0.998, 'entity_group': 'PER', 'start': 0, 'end': 3}, ...]
        res = []

        text_list = text.split("\n")
        input_list = []

        skip = 5
        for idx in range(0, len(text_list),skip):
            min_idx = idx
            max_idx = min(len(text_list), idx+skip)
            item = "\n".join(text_list[min_idx:max_idx])
            input_list.append(item)

        for item in input_list:
            # {'output': [{'type': 'LOC', 'start': 11, 'end': 14, 'prob': 0.28239322, 'span': '无限城'}, {'type': 'TIT', 'start': 17, 'end': 19, 'prob': 0.1941236, 'span': '哈总'}, {'type': 'TIT', 'start': 34, 'end': 37, 'prob': 0.14089614, 'span': '锻造师'}, {'type': 'PER', 'start': 55, 'end': 57, 'prob': 0.32835296, 'span': '路然'}, {'type': 'TIT', 'start': 88, 'end': 91, 'prob': 0.18094856, 'span': '林大师'}, {'type': 'WEA', 'start': 97, 'end': 99, 'prob': 0.3634123, 'span': '晶币'}]}
            results = ner_model(item)
            for result in results["output"]:
                if result["type"] in ["PER", "TIT"]:
                    print(result)


        return res
    except Exception as e:
        print(f"发生错误: {e}")
        return []

if __name__ == "__main__":
    text = """
第76章 沸腾的五号无限城
　　哈总愤怒。
　　本来它还挺欣赏这个锻造师，但没想到，对方也是这样的人！
　　路然无奈，其实只要牙齿已经可以了，至少不用骨头，他抬头问：“对了，林大师，总共要多少晶币？”
　　林大师沉思：“我算算，在风陨剑的基础上，我融合了稀有资源巨灵矿，高级资源寒铁，轻石、重石，辅助锻造的普通矿物资源若干，再加上锻造费。”
　　“总价格，差不多是5万晶币吧，零头我给你抹了。”
　　路然虽然已经有了心理准备，但知道自己给哈总升级了一把新武器花了5万晶币后，还是肉疼无比。
　　他露出微微痛苦的表情，终于体会到了那些成年人还房贷的艰辛。
　　“年轻人，定力就是不行！”林大师摇头：“我再给你详细介绍一遍冰空大剑好了！”
　　“冰空大剑，两种形态可以自由切换，除了基础的能量传导、增幅效果，还附带三个技能，举重若轻、举轻若重、牙岚！”
　　“两种形态自由切换，可以使它应对不同对手时选择更加灵活，毕竟大剑形态消耗体力严重，不过相对的，它的攻击力，在稀有武器中，绝对是顶呱呱。”
　　“让它越个种族等级、成长等级，那是轻轻松松。”
　　“嗯，考虑到你的宠兽不断在成长，我还加入了轻、重石，剑的重量，可以根据它的成长情况由它自己调节，换句话来说，这是一把可以改变重量的剑！”
　　“而牙岚，是依托于那上百颗牙齿的一个技能，是蕴含在剑内部的剑技，假如你的宠兽一丝能量也没有了，并且到了极为危机的时刻，可以牺牲那些内部的牙齿，换取一次超强的剑气爆发，瞬间挥出上百道剑气，算是一个压箱技。”
　　“当然，用完之后剑也相当于半报废了，需要补充新牙齿才能修补。”
　　“总之，你们现在只是看到了表面功能，稀有武器没那么简单！怎么样，现在是不是感觉物有所值了？”
　　路然听完，只是同情的看向了哈总，只感觉更费牙了。
　　哈总：。
　　。
　　不久后，路然离开了锻造之家，带着一屁股欠债，来到了三号无限城的传送广场。
　　除了锻剑，路然还买了一个高级弓弩，用于涂毒，一身暗抗衣服，用于抵御废弃试验场的魔能气息，一共花了1288晶币。
　　“这一去，不知道什么时候能回来。”
　　站在巨大的传送门附近，路然也判断不好，如果不顺利，在那边待个十天半个月都是有可能的。
　　“不过，不得不去。”穿着黑夜大衣的路然，踏进了传送区。
　　【是否花费100晶币传送至夏国五号无限城。】
　　“是。”路然确认，下一刻，他的身影消失在了人山人海的传送广场。
　　紧接着，随着光芒闪烁，来到了自己的专属房间。
　　路然打开门，这一回外界，不是那个居民小区了，而是另外一个传送广场，此次从专属房间出来，他是从传送门的光屏中走出的。
　　“这里就是五号无限城了啊。”路然只是看了一眼外边，就又回到传送门内，进入了专属房间，说是御兽师传送，但更像是，整个专属房间的空间跟着一起传送了过来。
　　并且坑钱的是，这个时候路然根本无法直接下线，得传送回三号无限城，才能回归到现实的传送位置，也就是得再花100晶币才能回归。
　　无意义的花销，也让很多御兽师没心思去其他无限城串门，只安心挑战自己城池的秘境。
　　专属房间内，路然来到了秘境柱台前，看向眼前的光幕。
　　秘境种类已经更新，虽然这里面大部分秘境，都和三号无限城没什么区别，但还是有个别秘境，是三号无限城没有的。
　　比如，废弃试验场，就是这个无限城的特色秘境。
　　【名称：废弃试验场】
　　【秘境等级：新手】
　　【难度：深渊】
　　【挑战晶币：1000】
　　路然迟疑了一下，放弃了在五号无限城逛一逛的打算，想立刻就挑战一次这个秘境看看！
　　魔牛统领头颅一甩，它高举斧头，向着路然他们的方向重重一砸。
　　轰！！！
　　瞬间，庞大的黑暗冲击波，像汹涌的浪潮一般朝着路然他们吞噬而来。
　　不过转瞬之间，又有耀眼的冰蓝色斩击，犹如破浪之刃，将黑色冲击波一分为二，直至此时，魔牛统领的本能才察觉到了一丝危机！
　　汪！！！（这上百颗牙的功力，你挡得住吗？！）
　　十倍剑气压缩的暴风斩，配合新武器冰空大剑，一瞬之间，劈开魔牛统领释放的黑暗冲击波，落到魔牛统领身上。
　　与此同时，哈总口中流出鲜血，牙齿摇摇欲晃，满脸的凶狠。
　　正如它所说，这上百颗牙的功力，怎么挡啊！
　　它的身后，路然手持神鹿项坠，一瞬间把它的伤势治好。
　　不过虽然反伤治好，但这一道极限暴风斩，直接掏空了哈总大半的力气，它已经无法放出第二道。
　　十倍剑气压缩的暴风斩，消耗不代表就等同释放十道剑气，反而对哈总的消耗极大。
　　“嗷呜！！！”一击而过，哈总呲牙看着前方烟雾升腾的区域，路然也目光凝重，耳边迟迟没有提示音传来，路然知道，这足以把龙尾蝎打的渣都不剩的一击，没能对这只魔牛统领造成致命伤害。
　　也对，那只龙尾蝎，只是野生的，但魔牛统领，却是一个御兽文明高度发达的御兽帝国制造的战争兵器实验品，相当于有无数御兽师的智慧结晶浓缩在它身上，怎么可能好对付。
　　“吼！！！！”果然，下一瞬，路然和哈总，就听到了一声愤怒的咆哮，烟雾被强烈的劲风挥去，转眼，就看见一只浑身包裹由黑暗能量塑造的魔能铠甲的牛头巨兽踩踏着废墟狂奔而来！！
　　“汪！！”叼着剑的哈总目瞪狗呆。
　　咚咚咚！魔牛统领每踏一步，都是地动山摇！
　　“哈总你行不行。”路然转头就跑，道：“什么时候考虑下领悟20倍暴风斩？”
　　“汪！！”看到魔牛冲撞而来，哈总也转头就跑，并把路然翻到身上。
　　20倍。别说牙齿了，它的狗头怕不是也不保！
　　总之，现在路然和哈总都牙疼至极，虽然预料到了这一次可能无法秒杀对手，但是真正经历到，他们好慌。
　　“吼！！”此时的牛头巨兽，魔能铠甲碎裂无数，身上也有黑色的鲜血冒出，一颗黑色牛角都被削成两半，但依然保持着极为亢奋的状态，手持巨斧，向着路然和哈总冲来。
　　还好，对于这种情况，路然也早有预案，哈总身上，路然扭身瞬间，一把弓弩出现在了他手中。
　　“哈总！”
　　电光火石之间，路然将涂毒的弓箭射出，并且同一时间，哈总也进行转身，利用剩下的力气，猛然吹出风之咆哮。
　　“嗷呜！！！”
　　飓风加速了有毒弓箭的推进，魔牛统领依然对防御没有什么意识，只知道进攻，完全没有在意看起来毫无威力的弓箭，而面对哈总的风之咆哮，它的脚步也没有受到什么阻碍。
　　唰。
　　弓箭插入魔牛统领的魔能铠甲、伤口缝隙，它毫无感觉的继续冲着，而看到弓箭一发入魂对方却没什么反应，路然和哈总也只能继续跑，没有和魔牛统领硬碰硬的打算。
　　利用好速度优势。
　　风筝流！斗牛！
　　“吼！！！”见到伤到自己的敌人逃走，且速度极快，魔牛统领不再追击，继续愤怒的挥舞巨斧，一道黑暗冲击波再次朝着路然它们吞噬而来。
　　黑色冲击波扫过，大地出现巨大的裂痕，犹如被黑色火焰炙烤，眼看黑色冲击波快速接近，逃跑中的哈总背后展开一对风之翼，迅速带着路然飞向天空。
　　轰隆！
　　巨坑之上，路然再次拿出弓弩，对准魔牛统领的眼睛，直接射去！
　　“傻了吧，还好我有先见之明，让哈总学会了风之翼！”
　　嗖！
　　又一发弓箭直接爆眼，路然的猎人血脉展露无疑，完全是百发百中。
　　狗都会飞，魔牛统领更加暴怒，全身能量流动加快，转瞬间，破碎的魔能铠甲有修复的趋势，扎入胸口和眼睛的弓箭，也瞬间被狂暴流动的能量冲掉，路然看魔牛统领进入了狂暴状态，没有敢再射，而是拍着哈总道：“跑！”
　　“拖时间！”
　　路然也不知道方澜给的毒液管不管用，但见哈总利用十倍暴风斩配合稀有武器冰空大剑也只是重创魔牛统领而没能秒杀它，顿时知道为什么深渊难度的秘境很少有人能单刷通关了。
　　这种难度。就算是四人组队能通关，也十分了不起。
　　接下来，就是魔牛统领和哈总耐力的比拼，不过相比魔牛统领，路然他们这边有制空优势，有补品优势，哈总一边飞，路然一边给它灌冰蜜茶，恢复着它的体力。
　　下方，魔牛统领不断发泄怒火，力量狂暴的砸在天空、大地，每一次路然和哈总都感觉在翻车边缘晃悠，还好有着暴风雪秘境的特训经验，哈总每次都成功躲开冲击，不然即使神鹿项坠能治愈伤害，也够他们喝一壶了。
　　就这样，路然和哈总大概和魔牛统领周旋了十几分钟。
　　哈总已经累得不成样子，而魔牛统领依然看起来精力充沛，让路然头皮发麻。
　　就在路然考虑要不要先放弃这次秘境时，突然，一道天籁之音，让路然浑身一震。
　　【恭喜你完成秘境挑战。】
　　【评分：S级！】
　　【恭喜你获得800晶币。】
　　【恭喜你获得高级资源，暗影矿。】
　　【恭喜你获得特殊资源，升级卡。】
　　【恭喜你获得特殊资源，特质水晶（武器掌控）。】
　　
　　声音落下，路然直接傻眼，不断拍着哈总的脑袋，狠狠拽着它的狗毛，让胯下的哈总都害怕了。
　　“呜呜。”
　　不明白路然一时间为什么这么亢奋。
　　不就是一次失败吗？牛头兽，让路总疯掉，这个仇。
　　但转眼，哈总似乎也知道怎么回事了，它向下看去，露出睿智的表情！
　　只见此时，刚才还很暴躁无比的魔牛统领，突然站在了原地不动，像是瞬间失去了全部生机，发光的眼睛也暗淡了下来。
　　“哞。”
　　意外的，它最后一道悲怆的声音，路然和哈总感觉自己能听懂。
　　哞。（卑鄙的入侵者，箭里有毒。）
　　它目光充满了不甘，庞大的身躯，重重倒在了地上，连同武器，一起化为碎片，随风而去。
　　“什么叫卑鄙，这叫战术！！”路然见状，哈哈大笑，更加用力拍起狗子，直接手动刹车，让哈总停了下来，现在路然恨不得把方澜找来狠狠抱住她，只感觉她就是自己的幸运女神，要不是方澜的毒液，路然感觉单凭他和哈总想耗死这只魔牛统领十分困难。
